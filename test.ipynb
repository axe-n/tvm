# %%
import numpy as np
import matplotlib.pyplot as plt

L,N,delt,delx,D= 100, 1000, 0.01, 0.1, 1.0

c = np.zeros(L)
c0=np.zeros(L)
K=(2*np.pi)/(L*delx)*np.concatenate((np.arange(0,L//2),np.arange(-L//2,0)))

x = np.arange(1,L+1)*delx

c0= np.exp(-0.5*(x-L*delx/2)**2/(0.1*L*delx)**2)
